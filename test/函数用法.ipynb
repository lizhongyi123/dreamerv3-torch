# %%
from collections import OrderedDict

od = OrderedDict()
od["episode01"] = {"reward": [1, 2, 3]}
od["episode02"] = {"reward": [4, 5]}
od["episode03"] =  [6, 7, 8]
print(od)
# Out:
# OrderedDict([('episode01', {'reward': [1, 2, 3]}), ('episode02', {'reward': [4, 5]}), ('episode03', [6, 7, 8])])

# %%
a = [1, 2, 3]
b = ['a', 'b', 'c']

c = zip(a, b)
print(list(c))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
pairs = [(1, 'a'), (2, 'b'), (3, 'c')]
print(*pairs)
print(list(zip(*pairs)))
# nums, chars = zip(*pairs)
#
# print(nums)   # (1, 2, 3)
# print(chars)  # ('a', 'b', 'c')
# Out:
# (1, 'a') (2, 'b') (3, 'c')
# [(1, 2, 3), ('a', 'b', 'c')]
