# %%
[({'orientations': array([ 0.95513636,  0.29616641,  0.64749939, -0.76206597,  0.99187027,
        0.12725314,  0.77872603,  0.62736414,  0.99400728, -0.1093139 ,
        0.80167489,  0.59776029,  0.61351438,  0.78968355]), 'height': [1.2990852322799866], 'velocity': array([-1.54309075e-02,  1.98061188e-01, -2.32878694e-01,  5.28247375e-01,
        2.34942264e+00, -2.40866447e+01, -4.50510830e+00,  4.89381296e+00,
        6.72545205e+00]), 'image': array([[[ 46,  68,  91],

        [ 38,  71, 103]]], dtype=uint8), 'is_terminal': False, 'is_first': False}, 0.34599643117411505, False, {'discount': array(1., dtype=float32)}),

 ({'orientations': array([ 0.85504674, -0.51855093, -0.27470249, -0.96152927,  0.75560518,
        0.65502734, -0.11159889,  0.99375333,  0.96824806, -0.24999137,
       -0.39450668,  0.91889307, -0.04668433,  0.99890969]), 'height': [1.2830673467207658], 'velocity': array([-0.70482185,  0.43267659, -0.83032705,  4.33049171,  0.55365874,
        0.27851274, -9.16069368,  6.77732961, 31.5080976 ]), 'image': array([[[ 46,  68,  91],
        [ 46,  68,  91],

        [ 65,  96, 130]]], dtype=uint8), 'is_terminal': False, 'is_first': False}, 0.3274721673794314, False, {'discount': array(1., dtype=float32)}),

 ({'orientations': array([ 0.89220562, -0.45162942,  0.99589959, -0.09046549,  0.61720621,
        0.78680143, -0.24491402,  0.9695448 ,  0.7513642 , -0.65988775,
        0.75820176,  0.65202001, -0.07006552,  0.99754239]), 'height': [1.3127770443471323], 'velocity': array([  0.39707997,   0.07700171,  -0.82266146,  -0.04836243,
         4.63687865, -23.15281981,  -8.49073785,  11.50232603,
        -0.19086298]), 'image': array([[[ 46,  68,  91],

        [ 65,  97, 130]]], dtype=uint8), 'is_terminal': False, 'is_first': False}, 0.32921581296222424, False, {'discount': array(1., dtype=float32)}),

 ({'orientations': array([ 0.93906663,  0.34373517,  0.62048938, -0.78421485,  0.65599224,
        0.75476763, -0.24368209,  0.96985516,  0.55152008, -0.83416162,
        0.44166572, -0.89717969,  0.98029275, -0.19755032]), 'height': [1.299927614457206], 'velocity': array([ -0.35547648,  -0.0844316 ,   0.98512312,   3.69646051,
         2.67100963, -14.54065061,   0.33311404,  -1.68004252,
         2.36816   ]), 'image': array([[[ 46,  68,  91],

        [ 65,  97, 130]]], dtype=uint8), 'is_terminal': False, 'is_first': False}, 0.33092547729083893, False, {'discount': array(1., dtype=float32)})]

# %%
({'orientations': array([ 0.95513636,  0.29616641,  0.64749939, -0.76206597,  0.99187027,
        0.12725314,  0.77872603,  0.62736414,  0.99400728, -0.1093139 ,
        0.80167489,  0.59776029,  0.61351438,  0.78968355]), 'height': [1.2990852322799866], 'velocity': array([-1.54309075e-02,  1.98061188e-01, -2.32878694e-01,  5.28247375e-01,
        2.34942264e+00, -2.40866447e+01, -4.50510830e+00,  4.89381296e+00,
        6.72545205e+00]), 'image': array([[[ 46,  68,  91],

        [ 38,  71, 103]]], dtype=uint8), 'is_terminal': False, 'is_first': False}, 0.34599643117411505, False)

# %%
({'orientations': array([ 0.95513636,  0.29616641,  0.64749939, -0.76206597,  0.99187027,
        0.12725314,  0.77872603,  0.62736414,  0.99400728, -0.1093139 ,
        0.80167489,  0.59776029,  0.61351438,  0.78968355]), 'height': [1.2990852322799866], 'velocity': array([-1.54309075e-02,  1.98061188e-01, -2.32878694e-01,  5.28247375e-01,
        2.34942264e+00, -2.40866447e+01, -4.50510830e+00,  4.89381296e+00,
        6.72545205e+00]), 'image': array([[[ 46,  68,  91],

        [ 38,  71, 103]]], dtype=uint8), 'is_terminal': False, 'is_first': False}, 0.34599643117411505, False, {'discount': array(1., dtype=float32)})

206 ({'orientations': array([ 0.95513636,  0.29616641,  0.64749939, -0.76206597,  0.99187027,
        0.12725314,  0.77872603,  0.62736414,  0.99400728, -0.1093139 ,
        0.80167489,  0.59776029,  0.61351438,  0.78968355]), 'height': [1.2990852322799866], 'velocity': array([-1.54309075e-02,  1.98061188e-01, -2.32878694e-01,  5.28247375e-01,
        2.34942264e+00, -2.40866447e+01, -4.50510830e+00,  4.89381296e+00,
        6.72545205e+00]), 'image': array([[[ 46,  68,  91],

        [ 38,  71, 103]]], dtype=uint8), 'is_terminal': False, 'is_first': False}, 0.34599643117411505, False)

209 (0.34599643117411505, 0.3274721673794314, 0.32921581296222424, 0.33092547729083893) (False, False, False, False)

# %%
# Dict(height: Box(-inf, inf, (1,), float32),
# image: Box(0, 255, (64, 64, 3), uint8),
# orientations: Box(-inf, inf, (14,), float32),
# velocity: Box( -inf, inf, (9,), float32))
# Box(-1.0, 1.0, (6,), float32)


# data = {
#     'image': [16, 50, H, W, C],  # 图像序列
#     'action': [16, 50, act_dim],  # 动作序列
#     'reward': [16, 50],  # 回报序列
#     'discount': [16, 50],  # 折扣因子
#     'is_first': [16, 50],  # 标记序列起点
#     ...
# }
